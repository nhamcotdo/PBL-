# %%
#!pip install tensorflow
# !pip install -U scikit-learn

# %%
import cv2
import mediapipe as mp
import numpy as np
import os
import pandas as pd
from PIL import Image
import numpy as np
import pandas as pd
# Import the required libraries.
import os
import cv2
import math
import random
import numpy as np
import datetime as dt
import tensorflow as tf
from collections import deque
import matplotlib.pyplot as plt
 
# %matplotlib inline
 
from sklearn.model_selection import train_test_split
 
from tensorflow.keras.layers import *
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.utils import plot_model
# Out:
# 2023-03-23 13:52:34.023814: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-23 13:52:34.195833: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/nhamcotdo/.local/lib/python3.10/site-packages/cv2/../../lib64:
# 2023-03-23 13:52:34.195854: I tensorflow/compiler/xla/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2023-03-23 13:52:35.085089: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/nhamcotdo/.local/lib/python3.10/site-packages/cv2/../../lib64:
# 2023-03-23 13:52:35.085198: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/nhamcotdo/.local/lib/python3.10/site-packages/cv2/../../lib64:
# 2023-03-23 13:52:35.085208: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
# Kích thướng mỗi frame
IMAGE_WIDTH,  IMAGE_HEIGHT = 160, 120
# số lượng frame sẽ lấy ở mỗi video
SEQUENCE_LENGTH = 20
# Những hành động sẽ nhận dạng
CLASSES_LIST = ['Your', 'Love', 'Sleep', 'Name',
                'What', 'Read', 'I', 'Bye', 'You', 'Eat', 'Hello']

# Link thư mục chứa video train
DATASET_DIR = './Create_data_set/dataset/'

# %%
files_list =  os.listdir(DATASET_DIR)
files_list
# Out:
# ['You.npz',
#  'What.npz',
#  'Read.npz',
#  'Sleep.npz',
#  'Hello.npz',
#  'Your.npz',
#  'Love.npz',
#  'Eat.npz',
#  'Bye.npz',
#  'I.npz',
#  'Name.npz']

# %%
# features = np.array([])
# labels = np.array([])
# for file_name in files_list:
#     print('Reading ', file_name, '. ... ..')
#     video_file_path = os.path.join(DATASET_DIR, file_name)
#     dataset = np.load(video_file_path)
#     feature = dataset['features']
#     label = dataset['labels']
#     print(feature.shape)
#     print(features.shape)
#     if features.any():
#         features = np.concatenate((features, feature), axis=0)
#     else:
#         features = feature
#     if labels.any():
#         labels = np.concatenate((labels, label), axis=0)
#     else:
#         labels = label

# %%
dataset = np.load('./Create_data_set/dataset_2.npz')
features=dataset['features']
labels=dataset['labels']
video_files_paths=dataset['video_files_paths']

# %%
features.shape
# Out:
# (209, 20, 120, 160, 3)

# %%
one_hot_encoded_labels = to_categorical(labels)

# %%
seed_constant = 27
np.random.seed(seed_constant)
random.seed(seed_constant)
tf.random.set_seed(seed_constant)

# %%
features_train, features_test, labels_train, labels_test = train_test_split(features, one_hot_encoded_labels, test_size = 0.2, shuffle = True, random_state = seed_constant)

# %%
def create_convlstm_model():
    '''
    This function will construct the required convlstm model.
    Returns:
        model: It is the required constructed convlstm model.
    '''
 
    # We will use a Sequential model for model construction
    model = Sequential()
 
    # Define the Model Architecture.
    ########################################################################################################################
    
    model.add(ConvLSTM2D(filters = 4, kernel_size = (3, 3), activation = 'tanh',data_format = "channels_last",
                         recurrent_dropout=0.2, return_sequences=True, input_shape = (SEQUENCE_LENGTH,
                                                                                      IMAGE_HEIGHT, IMAGE_WIDTH, 3)))
    
    model.add(MaxPooling3D(pool_size=(1, 2, 2), padding='same', data_format='channels_last'))
    model.add(TimeDistributed(Dropout(0.2)))
    
    model.add(ConvLSTM2D(filters = 8, kernel_size = (3, 3), activation = 'tanh', data_format = "channels_last",
                         recurrent_dropout=0.2, return_sequences=True))
    
    model.add(MaxPooling3D(pool_size=(1, 2, 2), padding='same', data_format='channels_last'))
    model.add(TimeDistributed(Dropout(0.2)))
    
    model.add(ConvLSTM2D(filters = 14, kernel_size = (3, 3), activation = 'tanh', data_format = "channels_last",
                         recurrent_dropout=0.2, return_sequences=True))
    
    model.add(MaxPooling3D(pool_size=(1, 2, 2), padding='same', data_format='channels_last'))
    model.add(TimeDistributed(Dropout(0.2)))
    
    model.add(ConvLSTM2D(filters = 16, kernel_size = (3, 3), activation = 'tanh', data_format = "channels_last",
                         recurrent_dropout=0.2, return_sequences=True))
    
    model.add(MaxPooling3D(pool_size=(1, 2, 2), padding='same', data_format='channels_last'))
    model.add(TimeDistributed(Dropout(0.2)))
    
    model.add(Flatten()) 
    
    model.add(Dense(len(CLASSES_LIST), activation = "softmax"))
    
    ########################################################################################################################
     
    # Display the models summary.
    model.summary()
    
    # Return the constructed convlstm model.
    return model

# %%
# Construct the required convlstm model.
convlstm_model = create_convlstm_model()
 
# Display the success message. 
print("Model Created Successfully!")
# Out:
# 2023-03-23 13:54:34.949879: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/nhamcotdo/.local/lib/python3.10/site-packages/cv2/../../lib64:
# 2023-03-23 13:54:34.949906: W tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:265] failed call to cuInit: UNKNOWN ERROR (303)
# 2023-03-23 13:54:34.949932: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (nhamcotdo): /proc/driver/nvidia/version does not exist
# 2023-03-23 13:54:34.950180: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv_lstm2d (ConvLSTM2D)    (None, 20, 158, 118, 4)   1024
#
#  max_pooling3d (MaxPooling3D  (None, 20, 79, 59, 4)    0
#  )
#
#  time_distributed (TimeDistr  (None, 20, 79, 59, 4)    0
#  ibuted)
#
#  conv_lstm2d_1 (ConvLSTM2D)  (None, 20, 77, 57, 8)     3488
#
#  max_pooling3d_1 (MaxPooling  (None, 20, 39, 29, 8)    0
#  3D)
#
#  time_distributed_1 (TimeDis  (None, 20, 39, 29, 8)    0
#  tributed)
#
#  conv_lstm2d_2 (ConvLSTM2D)  (None, 20, 37, 27, 14)    11144
#
#  max_pooling3d_2 (MaxPooling  (None, 20, 19, 14, 14)   0
#  3D)
#
#  time_distributed_2 (TimeDis  (None, 20, 19, 14, 14)   0
#  tributed)
#
#  conv_lstm2d_3 (ConvLSTM2D)  (None, 20, 17, 12, 16)    17344
#
#  max_pooling3d_3 (MaxPooling  (None, 20, 9, 6, 16)     0
#  3D)
#
#  time_distributed_3 (TimeDis  (None, 20, 9, 6, 16)     0
#  tributed)
#
#  flatten (Flatten)           (None, 17280)             0
#
#  dense (Dense)               (None, 11)                190091
#
# =================================================================
# Total params: 223,091
# Trainable params: 223,091
# Non-trainable params: 0
# _________________________________________________________________
# Model Created Successfully!

# %%
plot_model(convlstm_model, to_file = 'convlstm_model_structure_plot.png', show_shapes = True, show_layer_names = True)

# %%
# !pip install pydot

# %%
# early_stopping_callback = EarlyStopping(monitor = 'val_loss', patience = 10, mode = 'min', restore_best_weights = True)
 
# # Compile the model and specify loss function, optimizer and metrics values to the model
# convlstm_model.compile(loss = 'categorical_crossentropy', optimizer = 'Adam', metrics = ["accuracy"])
 
# # Start training the model.
# convlstm_model_training_history = convlstm_model.fit(x = features_train, y = labels_train, epochs = 50, batch_size = 1,shuffle = True, validation_split = 0.2, callbacks = [early_stopping_callback])

# %%
 	
# Evaluate the trained model.
# model_evaluation_history = convlstm_model.evaluate(features_test, labels_test)

# %%
# model_evaluation_loss, model_evaluation_accuracy = model_evaluation_history
 
# # Define the string date format.
# # Get the current Date and Time in a DateTime Object.
# # Convert the DateTime object to string according to the style mentioned in date_time_format string.
# date_time_format = '%Y_%m_%d__%H_%M_%S'
# current_date_time_dt = dt.datetime.now()
# current_date_time_string = dt.datetime.strftime(current_date_time_dt, date_time_format)
 
# # Define a useful name for our model to make it easy for us while navigating through multiple saved models.
# model_file_name = f'convlstm_model___Date_Time_{current_date_time_string}___Loss_{model_evaluation_loss}___Accuracy_{model_evaluation_accuracy}.h5'
 
# # Save your Model.
# convlstm_model.save(model_file_name)

# %%
def create_LRCN_model():
    '''
    This function will construct the required LRCN model.
    Returns:
        model: It is the required constructed LRCN model.
    '''

    # We will use a Sequential model for model construction.
    model = Sequential()
    
    # Define the Model Architecture.
    ########################################################################################################################
    
    model.add(TimeDistributed(Conv2D(16, (3, 3), padding='same',activation = 'relu'),
                              input_shape = (SEQUENCE_LENGTH,IMAGE_HEIGHT, IMAGE_WIDTH, 3)))
    
    model.add(TimeDistributed(MaxPooling2D((4, 4)))) 
    model.add(TimeDistributed(Dropout(0.25)))
    
    model.add(TimeDistributed(Conv2D(32, (3, 3), padding='same',activation = 'relu')))
    model.add(TimeDistributed(MaxPooling2D((4, 4))))
    model.add(TimeDistributed(Dropout(0.25)))
    
    model.add(TimeDistributed(Conv2D(64, (3, 3), padding='same',activation = 'relu')))
    model.add(TimeDistributed(MaxPooling2D((2, 2))))
    model.add(TimeDistributed(Dropout(0.25)))
    
    model.add(TimeDistributed(Conv2D(64, (3, 3), padding='same',activation = 'relu')))
    model.add(TimeDistributed(MaxPooling2D((2, 2))))
    #model.add(TimeDistributed(Dropout(0.25)))
                                      
    model.add(TimeDistributed(Flatten()))
                                      
    model.add(LSTM(32))
                                      
    model.add(Dense(len(CLASSES_LIST), activation = 'softmax'))

    ########################################################################################################################

    # Display the models summary.
    model.summary()
    
    # Return the constructed LRCN model.
    return model

# %%
LRCN_model = create_LRCN_model()
 
# Display the success message.
print("Model Created Successfully!")
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed_16 (TimeDi  (None, 20, 120, 160, 16)  448
#  stributed)
#
#  time_distributed_17 (TimeDi  (None, 20, 30, 40, 16)   0
#  stributed)
#
#  time_distributed_18 (TimeDi  (None, 20, 30, 40, 16)   0
#  stributed)
#
#  time_distributed_19 (TimeDi  (None, 20, 30, 40, 32)   4640
#  stributed)
#
#  time_distributed_20 (TimeDi  (None, 20, 7, 10, 32)    0
#  stributed)
#
#  time_distributed_21 (TimeDi  (None, 20, 7, 10, 32)    0
#  stributed)
#
#  time_distributed_22 (TimeDi  (None, 20, 7, 10, 64)    18496
#  stributed)
#
#  time_distributed_23 (TimeDi  (None, 20, 3, 5, 64)     0
#  stributed)
#
#  time_distributed_24 (TimeDi  (None, 20, 3, 5, 64)     0
#  stributed)
#
#  time_distributed_25 (TimeDi  (None, 20, 3, 5, 64)     36928
#  stributed)
#
#  time_distributed_26 (TimeDi  (None, 20, 1, 2, 64)     0
#  stributed)
#
#  time_distributed_27 (TimeDi  (None, 20, 128)          0
#  stributed)
#
#  lstm_1 (LSTM)               (None, 32)                20608
#
#  dense_2 (Dense)             (None, 11)                363
#
# =================================================================
# Total params: 81,483
# Trainable params: 81,483
# Non-trainable params: 0
# _________________________________________________________________
# Model Created Successfully!

# %%
early_stopping_callback = EarlyStopping(monitor = 'val_loss', patience = 15, mode = 'min', restore_best_weights = True)
 
# Compile the model and specify loss function, optimizer and metrics to the model.
LRCN_model.compile(loss = 'categorical_crossentropy', optimizer = 'Adam', metrics = ["accuracy"])
 
# Start training the model.
LRCN_model_training_history = LRCN_model.fit(x = features_train, y = labels_train, epochs = 70, batch_size = 1 , shuffle = True, validation_split = 0.2, callbacks = [early_stopping_callback])
# Out:
# Epoch 1/70
# 2023-03-23 13:55:49.438114: W tensorflow/tsl/framework/cpu_allocator_impl.cc:82] Allocation of 612864000 exceeds 10% of free system memory.
# 133/133 [==============================] - 31s 205ms/step - loss: 2.4603 - accuracy: 0.0677 - val_loss: 2.3858 - val_accuracy: 0.1176
# Epoch 2/70
# 133/133 [==============================] - 27s 204ms/step - loss: 2.3703 - accuracy: 0.1579 - val_loss: 2.3131 - val_accuracy: 0.2059
# Epoch 3/70
# 133/133 [==============================] - 32s 240ms/step - loss: 2.3389 - accuracy: 0.1654 - val_loss: 2.3044 - val_accuracy: 0.1765
# Epoch 4/70
# 133/133 [==============================] - 29s 219ms/step - loss: 2.1889 - accuracy: 0.2180 - val_loss: 2.1802 - val_accuracy: 0.2647
# Epoch 5/70
# 133/133 [==============================] - 28s 213ms/step - loss: 2.0475 - accuracy: 0.2782 - val_loss: 2.0187 - val_accuracy: 0.3529
# Epoch 6/70
# 133/133 [==============================] - 28s 209ms/step - loss: 1.8994 - accuracy: 0.3534 - val_loss: 2.1102 - val_accuracy: 0.2941
# Epoch 7/70
# 133/133 [==============================] - 29s 218ms/step - loss: 1.7683 - accuracy: 0.3910 - val_loss: 2.2971 - val_accuracy: 0.2941
# Epoch 8/70
# 133/133 [==============================] - 28s 213ms/step - loss: 1.7180 - accuracy: 0.4286 - val_loss: 1.8735 - val_accuracy: 0.3529
# Epoch 9/70
# 133/133 [==============================] - 28s 209ms/step - loss: 1.4762 - accuracy: 0.5338 - val_loss: 1.9892 - val_accuracy: 0.2353
# Epoch 10/70
# 133/133 [==============================] - 28s 210ms/step - loss: 1.5806 - accuracy: 0.5113 - val_loss: 1.8021 - val_accuracy: 0.3824
# Epoch 11/70
# 133/133 [==============================] - 21s 158ms/step - loss: 1.3854 - accuracy: 0.5714 - val_loss: 1.6965 - val_accuracy: 0.5882
# Epoch 12/70
# 133/133 [==============================] - 19s 141ms/step - loss: 1.2640 - accuracy: 0.6391 - val_loss: 1.6847 - val_accuracy: 0.4118
# Epoch 13/70
# 133/133 [==============================] - 19s 139ms/step - loss: 1.1201 - accuracy: 0.6617 - val_loss: 1.4944 - val_accuracy: 0.5294
# Epoch 14/70
# 133/133 [==============================] - 18s 133ms/step - loss: 1.0775 - accuracy: 0.6842 - val_loss: 1.6121 - val_accuracy: 0.5882
# Epoch 15/70
# 133/133 [==============================] - 30s 229ms/step - loss: 0.9367 - accuracy: 0.7293 - val_loss: 1.4406 - val_accuracy: 0.6176
# Epoch 16/70
# 133/133 [==============================] - 28s 208ms/step - loss: 0.8024 - accuracy: 0.8120 - val_loss: 1.4182 - val_accuracy: 0.5882
# Epoch 17/70
# 133/133 [==============================] - 27s 202ms/step - loss: 0.7486 - accuracy: 0.8120 - val_loss: 1.2821 - val_accuracy: 0.7059
# Epoch 18/70
# 133/133 [==============================] - 28s 210ms/step - loss: 0.6784 - accuracy: 0.8271 - val_loss: 1.2294 - val_accuracy: 0.6471
# Epoch 19/70
# 133/133 [==============================] - 28s 208ms/step - loss: 0.7122 - accuracy: 0.8195 - val_loss: 1.4050 - val_accuracy: 0.5588
# Epoch 20/70
# 133/133 [==============================] - 27s 202ms/step - loss: 0.5880 - accuracy: 0.8571 - val_loss: 1.4402 - val_accuracy: 0.5882
# Epoch 21/70
# 133/133 [==============================] - 28s 207ms/step - loss: 0.5641 - accuracy: 0.8647 - val_loss: 1.2047 - val_accuracy: 0.7353
# Epoch 22/70
# 133/133 [==============================] - 27s 200ms/step - loss: 0.5120 - accuracy: 0.8722 - val_loss: 1.4525 - val_accuracy: 0.6176
# Epoch 23/70
# 133/133 [==============================] - 27s 200ms/step - loss: 0.5211 - accuracy: 0.8872 - val_loss: 1.2959 - val_accuracy: 0.6471
# Epoch 24/70
# 133/133 [==============================] - 27s 205ms/step - loss: 0.4681 - accuracy: 0.8722 - val_loss: 1.2609 - val_accuracy: 0.6471
# Epoch 25/70
# 133/133 [==============================] - 25s 187ms/step - loss: 0.4120 - accuracy: 0.8797 - val_loss: 1.2991 - val_accuracy: 0.6176
# Epoch 26/70
# 133/133 [==============================] - 39s 292ms/step - loss: 0.2198 - accuracy: 0.9774 - val_loss: 1.1181 - val_accuracy: 0.6176
# Epoch 27/70
# 133/133 [==============================] - 31s 230ms/step - loss: 0.2414 - accuracy: 0.9549 - val_loss: 1.0499 - val_accuracy: 0.7353
# Epoch 28/70
# 133/133 [==============================] - 33s 249ms/step - loss: 0.1964 - accuracy: 0.9774 - val_loss: 1.1279 - val_accuracy: 0.6765
# Epoch 29/70
# 133/133 [==============================] - 39s 291ms/step - loss: 0.1717 - accuracy: 0.9774 - val_loss: 1.1359 - val_accuracy: 0.7647
# Epoch 30/70
# 133/133 [==============================] - 25s 189ms/step - loss: 0.1370 - accuracy: 0.9850 - val_loss: 1.0455 - val_accuracy: 0.7059
# Epoch 31/70
# 133/133 [==============================] - 24s 181ms/step - loss: 0.1096 - accuracy: 0.9925 - val_loss: 1.0383 - val_accuracy: 0.7353
# Epoch 32/70
# 133/133 [==============================] - 36s 272ms/step - loss: 0.1052 - accuracy: 0.9850 - val_loss: 1.0690 - val_accuracy: 0.7353
# Epoch 33/70
# 133/133 [==============================] - 27s 200ms/step - loss: 0.0963 - accuracy: 0.9850 - val_loss: 1.2234 - val_accuracy: 0.5882
# Epoch 34/70
# 133/133 [==============================] - 35s 261ms/step - loss: 0.0997 - accuracy: 0.9925 - val_loss: 1.0729 - val_accuracy: 0.7059
# Epoch 35/70
# 133/133 [==============================] - 49s 369ms/step - loss: 0.0927 - accuracy: 0.9850 - val_loss: 1.0235 - val_accuracy: 0.7059
# Epoch 36/70
# 133/133 [==============================] - 49s 366ms/step - loss: 0.4526 - accuracy: 0.8496 - val_loss: 1.1805 - val_accuracy: 0.7059
# Epoch 37/70
# 133/133 [==============================] - 42s 318ms/step - loss: 0.2501 - accuracy: 0.9624 - val_loss: 1.0652 - val_accuracy: 0.7353
# Epoch 38/70
# 133/133 [==============================] - 33s 249ms/step - loss: 0.2378 - accuracy: 0.9474 - val_loss: 1.4491 - val_accuracy: 0.5294
# Epoch 39/70
# 133/133 [==============================] - 27s 206ms/step - loss: 0.1453 - accuracy: 0.9850 - val_loss: 1.1753 - val_accuracy: 0.6765
# Epoch 40/70
# 133/133 [==============================] - 37s 279ms/step - loss: 0.0891 - accuracy: 0.9925 - val_loss: 1.3160 - val_accuracy: 0.5882
# Epoch 41/70
# 133/133 [==============================] - 30s 229ms/step - loss: 0.0892 - accuracy: 0.9850 - val_loss: 1.1103 - val_accuracy: 0.7353
# Epoch 42/70
# 133/133 [==============================] - 20s 151ms/step - loss: 0.0570 - accuracy: 1.0000 - val_loss: 1.1652 - val_accuracy: 0.7353
# Epoch 43/70
# 133/133 [==============================] - 23s 171ms/step - loss: 0.0535 - accuracy: 1.0000 - val_loss: 1.4527 - val_accuracy: 0.7059
# Epoch 44/70
# 133/133 [==============================] - 28s 210ms/step - loss: 0.0470 - accuracy: 0.9925 - val_loss: 1.4482 - val_accuracy: 0.7353
# Epoch 45/70
# 133/133 [==============================] - 28s 208ms/step - loss: 0.0551 - accuracy: 1.0000 - val_loss: 1.4226 - val_accuracy: 0.6471
# Epoch 46/70
# 133/133 [==============================] - 28s 209ms/step - loss: 0.0431 - accuracy: 1.0000 - val_loss: 1.1845 - val_accuracy: 0.7059
# Epoch 47/70
# 133/133 [==============================] - 27s 203ms/step - loss: 0.0298 - accuracy: 1.0000 - val_loss: 1.1722 - val_accuracy: 0.6765
# Epoch 48/70
# 133/133 [==============================] - 27s 202ms/step - loss: 0.0328 - accuracy: 1.0000 - val_loss: 1.3559 - val_accuracy: 0.7059
# Epoch 49/70
# 133/133 [==============================] - 41s 310ms/step - loss: 0.0270 - accuracy: 1.0000 - val_loss: 1.3669 - val_accuracy: 0.7353
# Epoch 50/70
# 133/133 [==============================] - 20s 150ms/step - loss: 0.0211 - accuracy: 1.0000 - val_loss: 1.2776 - val_accuracy: 0.7353

# %%
model_evaluation_history = LRCN_model.evaluate(features_test, labels_test)

# %%
model_evaluation_loss, model_evaluation_accuracy = model_evaluation_history
 
# Define the string date format.
# Get the current Date and Time in a DateTime Object.
# Convert the DateTime object to string according to the style mentioned in date_time_format string.
date_time_format = '%Y_%m_%d__%H_%M_%S'
current_date_time_dt = dt.datetime.now()
current_date_time_string = dt.datetime.strftime(current_date_time_dt, date_time_format)
    
# Define a useful name for our model to make it easy for us while navigating through multiple saved models.
model_file_name = f'LRCN_model___Date_Time_{current_date_time_string}___Loss_{model_evaluation_loss}___Accuracy_{model_evaluation_accuracy}.h5'
 
# Save the Model.
LRCN_model.save(model_file_name)

# %%
print("GPUs Available: ", tf.config.list_physical_devices('GPU'))
